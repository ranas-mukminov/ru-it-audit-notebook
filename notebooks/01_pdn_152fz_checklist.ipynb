# %% [markdown]
# # ПДн / 152-ФЗ

# %%
inventory_path = 'examples/inventory/sample_inventory.csv'
answers_dir = 'examples/inputs'

# %%
from pathlib import Path
import yaml

checklist_path = Path('checklists/pdn_152fz.yaml')
answers_file = Path(answers_dir) / 'sample_answers_pdn.yaml'
data = yaml.safe_load(checklist_path.read_text(encoding='utf-8'))
answers = yaml.safe_load(answers_file.read_text(encoding='utf-8')) if answers_file.exists() else {}
print('Вопросов в чек-листе:', len(data.get('controls', [])))
print('Ответов получено:', len(answers.get('answers', {})))
