# %% [markdown]
# # Инвентаризация серверов

# %%
inventory_path = 'examples/inventory/sample_inventory.csv'
answers_dir = 'examples/inputs'

# %%
import pandas as pd
from pathlib import Path

inv = Path(inventory_path)
if inv.exists():
    df = pd.read_csv(inv)
    print('Всего узлов:', len(df))
    print('По ОС:', df['os'].value_counts().to_dict())
else:
    print('inventory file not found')
