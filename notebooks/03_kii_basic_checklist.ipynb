# %% [markdown]
# # Базовые вопросы КИИ

# %%
inventory_path = 'examples/inventory/sample_inventory.csv'
answers_dir = 'examples/inputs'

# %%
from pathlib import Path
import yaml

path = Path('checklists/kii_basic.yaml')
checks = yaml.safe_load(path.read_text(encoding='utf-8'))
print('Контролей в КИИ-чеклисте:', len(checks.get('controls', [])))
